# %% [markdown]
# <style>
# rendered_html {
#   font-size:0.5em;
# }
# </style>
# <center>
#     <h1>[SageMath](http://sagemath.org) en cinq minutes</h1>
#
# <br>
#   <large><a href="http://Nicolas.Thiery.name">Nicolas M. Thiéry</a></large><br>
#   <a href="http://lri.fr">Laboratoire de Recherche en Informatique</a><br>
#   <a href="http://www.u-psud.fr">Université Paris Sud</a><br><br>
#
#
#   PyParis <br>
#   Session Python pour l'Éducation<br>
#   September 28rd of 2018<br><br>
#
#   <a href="https://mybinder.org/v2/gh/nthiery/shared-sage-notebooks/master?filepath=2018-11-14-PyParis-Education-SageMath.ipynb">Ce document actif</a> sur <a href="https://mybinder.org">Binder</a><br>
#
#   Shorthand: https://tinyurl.com/pyparis18-education-sage
# </center>

# %% [markdown]
# ## [SageMath](sagemath.org) en deux mots

# %% [markdown]
# - Un système de calcul généraliste pour les mathématiques

# %% [markdown]
# - Basé sur Python (Python 2; port vers Python 3 en cours)<br>
#   Et une multitude de bibliothèques de calculs

# %% [markdown]
# - Licence libre, gratuit
# - Multi-plateforme: Linux, Windows, MacOS<br>
#   ou en ligne (par exemple sur [CoCalc](cocalc.com))

# %% [markdown]
# - Développé par une communauté d'enseignants, chercheurs, ingénieurs, ...<br>
# - 3-4 versions par an depuis 2005; ~100 contributeurs par version
# - Financements: NSF (USA), H2020 (Europe), ...

# %% [markdown]
# - Utilisé à l'université (L1 -> agreg, doctorat), en recherche, ...
# - Au lycée?

# %% [markdown]
# ## [SageMath](http://sagemath.org) en démo

# %% [markdown]
# ## Arithmétique: de l'exact au numérique à précision arbitraire

# %%
1 + 1
# Out:
# 2

# %%
( 1 + 2 * (3 + 5)^2 ) * 2
# Out:
# 258

# %%
20/14
# Out:
# 10/7

# %%
2^1000
# Out:
# 

# %%
20.0/14
# Out:
# 1.42857142857143

# %%
numerical_approx(4*arctan(1), 10000)
# Out:
# 3....

# %% [markdown]
# ## Arithmétique: nombres premiers, modulo, corps fini; codage RSA?

# %%
p = next_prime(2^9);
p
# Out:
# 521

# %%
550 % p
# Out:
# 29

# %%
Zp = FiniteField(p)

# %%
a = Zp(550); a
# Out:
# 29

# %%
a^(7^7^7)
# Out:
# 226

# %%
Zp.category()
# Out:
# Join of Category of finite enumerated fields and Category of subquotients of monoids and Category of quotients of semigroups

# %%
Zp.category().axioms()
# Out:
# frozenset({'AdditiveAssociative',
#            'AdditiveCommutative',
#            'AdditiveInverse',
#            'AdditiveUnital',
#            'Associative',
#            'Commutative',
#            'Distributive',
#            'Division',
#            'Enumerated',
#            'Finite',
#            'NoZeroDivisors',
#            'Unital'})

# %% [markdown]
# ## Un peu d'algèbre

# %%
var('x,y')
# Out:
# (x, y)

# %%
factor(x^100 - 1)
# Out:
# (x^40 - x^30 + x^20 - x^10 + 1)*(x^20 + x^15 + x^10 + x^5 + 1)*(x^20 - x^15 + x^10 - x^5 + 1)*(x^8 - x^6 + x^4 - x^2 + 1)*(x^4 + x^3 + x^2 + x + 1)*(x^4 - x^3 + x^2 - x + 1)*(x^2 + 1)*(x + 1)*(x - 1)

# %%
# %display latex

# %%
factor(x^100 -1)
# Out:
# (x^40 - x^30 + x^20 - x^10 + 1)*(x^20 + x^15 + x^10 + x^5 + 1)*(x^20 - x^15 + x^10 - x^5 + 1)*(x^8 - x^6 + x^4 - x^2 + 1)*(x^4 + x^3 + x^2 + x + 1)*(x^4 - x^3 + x^2 - x + 1)*(x^2 + 1)*(x + 1)*(x - 1)

# %%
solve([x^2+y^2 == 1, y^2 == x^3 + x + 1], x, y)
# Out:
# [[x == -1/2*I*sqrt(3) - 1/2, y == -sqrt(-1/2*I*sqrt(3) + 3/2)], [x == -1/2*I*sqrt(3) - 1/2, y == sqrt(-1/2*I*sqrt(3) + 3/2)], [x == 1/2*I*sqrt(3) - 1/2, y == -sqrt(1/2*I*sqrt(3) + 3/2)], [x == 1/2*I*sqrt(3) - 1/2, y == sqrt(1/2*I*sqrt(3) + 3/2)], [x == 0, y == -1], [x == 0, y == 1]]

# %% [markdown]
# ## Un peu d'analyse

# %%
f = (cos(pi/4-x)-tan(x)) / (1-sin(pi/4 + x)); f
# Out:
# -(cos(1/4*pi - x) - tan(x))/(sin(1/4*pi + x) - 1)

# %%
f.derivative()
# Out:
# (tan(x)^2 - sin(1/4*pi - x) + 1)/(sin(1/4*pi + x) - 1) + (cos(1/4*pi - x) - tan(x))*cos(1/4*pi + x)/(sin(1/4*pi + x) - 1)^2

# %%
limit(f, x = pi/4, dir='minus')
# Out:
# +Infinity

# %%
f = cos(x)^6 + sin(x)^6 + 3 * sin(x)^2 * cos(x)^2; f
# Out:
# cos(x)^6 + sin(x)^6 + 3*cos(x)^2*sin(x)^2

# %%
f.simplify_trig()
# Out:
# 1

# %% [markdown]
# ## Graphiques

# %%
plot(x*sin(1/x))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ### Graphique et programmation : marche aléatoire

# %%
n, l, x, y = 10000, 1, 0, 0
p = [[0, 0]]

for k in range(n):
    theta = (2 * pi * random()).n(digits=5)
    x, y = x + l * cos(theta), y + l * sin(theta)
    p.append([x, y])

g = line(p, thickness=.4) + line([p[n], [0, 0]], color='red', thickness=2)
g.show(aspect_ratio=1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Graphiques interactifs

# %%
@interact
def g(f=x*sin(1/x), 
      c=slider(-1, 1, .01, default=-.5), 
      n=(1..30),
      xinterval=range_slider(-1, 1, .1, default=(-8,8), label="x-interval"),
      yinterval=range_slider(-1, 1, .1, default=(-3,3), label="y-interval")):
    x0 = c
    degree = n
    xmin,xmax = xinterval
    ymin,ymax = yinterval
    p   = plot(f, xmin, xmax, thickness=4)
    dot = point((x0,f(x=x0)),pointsize=80,rgbcolor=(1,0,0))
    ft = f.taylor(x,x0,degree)
    pt = plot(ft, xmin, xmax, color='red', thickness=2, fill=f)
    show(dot + p + pt, ymin=ymin, ymax=ymax, xmin=xmin, xmax=xmax)
    html('$f(x)\;=\;%s$'%latex(f))
    html('$P_{%s}(x)\;=\;%s+R_{%s}(x)$'%(degree,latex(ft),degree))
# Out:
# SW50ZXJhY3RpdmUgZnVuY3Rpb24gPGZ1bmN0aW9uIGcgYXQgMHg3ZjRhMGM1MWJiMTg+IHdpdGggNSB3aWRnZXRzCiAgZjogRmxvYXRTbGlkZXIodmFsdWU9MC45OTk5MjA4NDUwMzE3MzgzLCDigKY=

# %% [markdown]
# ### Graphiques 3D

# %%
var('x,y')
plot3d(sin(pi*sqrt(x^2+y^2)) / sqrt(x^2+y^2), (x,-5,5), (y,-5,5), viewer="threejs")
# Out:
# Graphics3d Object

# %%
polytopes.truncated_icosidodecahedron().plot(viewer="threejs")
# Out:
# Graphics3d Object

# %% [markdown]
# ## Combinatoire et probabilités discrètes

# %%
# %display ascii_art

# %%
Symboles = Set(["Coeur", "Carreau", "Pique", "Trefle"])
Valeurs  = Set([2, 3, 4, 5, 6, 7, 8, 9, 10, "Valet", "Dame", "Roi", "As"])
Cartes   = cartesian_product([Valeurs, Symboles])
Mains    = Subsets(Cartes, 5)

# %%
Mains.random_element()
# Out:
# {(8, 'Pique'), (6, 'Carreau'), (5, 'Trefle'), (6, 'Coeur'), ('Roi', 'Pique')}

# %%
Mains.cardinality()
# Out:
# 2598960

# %%
Couleurs = cartesian_product([Subsets(Valeurs, 5), Symboles])
Couleurs.random_element()
# Out:
# ( {'Roi', 'As', 4, 6, 'Dame'}, Coeur )

# %%
float( Couleurs.cardinality() / Mains.cardinality() )
# Out:
# 0.00198079231693

# %%
Mains.cardinality??

# %% [markdown]
# ## Théorie des graphes

# %%
graphs
# Out:
# <sage.graphs.graph_generators.GraphGenerators instance at 0x7f4a08cc7b00>

# %%
g = graphs.PetersenGraph(); g
# Out:
# Petersen graph: Graph on 10 vertices

# %%
g.plot(partition=g.coloring())
# Out:
# Graphics object consisting of 26 graphics primitives

# %% [markdown]
# ## SageMath
# - Un environnement confortable et homogène (Jupyter)
# - Pour la programmation et les mathématiques (Python)
# - Libre, gratuit, pérenne, multiplateforme
# - Inclut Numpy, Scipy, Matplotlib, ...

# %% [markdown]
# ## Livres
# - <img align="right" width="15%" src="CalculMathematiqueAvecSage.jpg">
#   [Calcul Mathématique avec SageMath](http://sagebook.gforge.inria.fr/)<br>
#   2013, libre, 12€, [en anglais](http://sagebook.gforge.inria.fr/english.html) (2018), [en allemand](www.loria.fr/~zimmerma/sagebook/CalculDeutsch.pdf)
# - [SageMath for undergraduates](http://www.gregorybard.com/Sage.html), Gregory Bard
# - SageMath au lycée???
